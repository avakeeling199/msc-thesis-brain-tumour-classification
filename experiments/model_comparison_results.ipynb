# %%
# load in data
import pandas as pd

all_results = pd.read_csv("../results/all_model_results.csv")

# %%
all_results
# Out:
#     Architecture Classifier  Fold  Accuracy  Precision    Recall  Specificity  \
# 0          VGG16    softmax     1  0.858392   0.882993  0.854351     0.953057
# 1          VGG16    softmax     2  0.868881   0.882975  0.864256     0.956293
# 2          VGG16    softmax     3  0.851138   0.874507  0.849737     0.952597
# 3          VGG16    softmax     4  0.823117   0.833119  0.827051     0.942253
# 4          VGG16    softmax     5  0.831874   0.869246  0.831545     0.944599
# ..           ...        ...   ...       ...        ...       ...          ...
# 145     Xception         rf     6  0.884413   0.880505  0.875898     0.961627
# 146     Xception         rf     7  0.851138   0.852430  0.853433     0.950109
# 147     Xception         rf     8  0.856392   0.849960  0.849670     0.952666
# 148     Xception         rf     9  0.851138   0.843460  0.845326     0.951214
# 149     Xception         rf    10  0.868651   0.865078  0.863416     0.956307
#
# ...

# %%
summary = all_results.groupby(["Architecture", "Classifier"]).agg({
    "Accuracy": ["mean", "std"],
    "F1 Score": ["mean", "std"],
    "Precision": ["mean", "std"],
    "Recall": ["mean", "std"],
    "Specificity": ["mean", "std"],
    "ROC AUC": ["mean", "std"],
    "training_time": "mean",
}).reset_index()

# %%
summary
# Out:
#    Architecture Classifier  Accuracy            F1 Score           Precision  \
#                                 mean       std      mean       std      mean
# 0   DenseNet121         rf  0.919819  0.009786  0.916517  0.010328  0.918884
# 1   DenseNet121    softmax  0.869927  0.029726  0.868009  0.030020  0.885895
# 2   DenseNet121        svm  0.921570  0.011944  0.918660  0.011307  0.921714
# 3   InceptionV3         rf  0.855396  0.017997  0.848381  0.016473  0.851462
# 4   InceptionV3    softmax  0.814948  0.022393  0.809919  0.024647  0.832386
# 5   InceptionV3        svm  0.908615  0.009643  0.904401  0.009215  0.906487
# 6     ResNet101         rf  0.875354  0.015860  0.869405  0.015435  0.871405
# 7     ResNet101    softmax  0.824048  0.023807  0.821761  0.024494  0.843195
# 8     ResNet101        svm  0.860994  0.014125  0.855719  0.013753  0.857571
# 9         VGG16         rf  0.916844  0.012749  0.913858  0.013267  0.916847
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.barplot(
    data=summary,
    x="Architecture",
    y=("Accuracy", "mean"),
    hue="Classifier",
    capsize=0.1
)
plt.title("Mean Accuracy by Architecture and Classifier")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.barplot(
    data=summary,
    x="Architecture",
    y=("F1 Score", "mean"),
    hue="Classifier",
    capsize=0.1
)
plt.title("Mean F1 Score by Architecture and Classifier")
plt.ylabel("Accuracy")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_f1 = summary.sort_values(by=("F1 Score", "mean"), ascending=False).head(5)
print(top_f1)
# Out:
#    Architecture Classifier  Accuracy            F1 Score           Precision  \
#                                 mean       std      mean       std      mean
# 2   DenseNet121        svm  0.921570  0.011944  0.918660  0.011307  0.921714
# 0   DenseNet121         rf  0.919819  0.009786  0.916517  0.010328  0.918884
# 9         VGG16         rf  0.916844  0.012749  0.913858  0.013267  0.916847
# 14     Xception        svm  0.916493  0.010163  0.912831  0.010573  0.914920
# 5   InceptionV3        svm  0.908615  0.009643  0.904401  0.009215  0.906487
#
#                 Recall           Specificity             ROC AUC            \
#          std      mean       std        mean       std      mean       std
# 2   0.011610  0.918123  0.010391    0.974049  0.003915  0.989629  0.002092
# 0   0.010752  0.916345  0.009144    0.973476  0.003092  0.989855  0.001672
# 9   0.013545  0.913626  0.011950    0.972461  0.004008  0.988320  0.001904
# ...

# %%
top_auc = summary.sort_values(by=("ROC AUC", "mean"), ascending=False).head(5)
print(top_auc)
# Out:
#    Architecture Classifier  Accuracy            F1 Score           Precision  \
#                                 mean       std      mean       std      mean
# 0   DenseNet121         rf  0.919819  0.009786  0.916517  0.010328  0.918884
# 2   DenseNet121        svm  0.921570  0.011944  0.918660  0.011307  0.921714
# 9         VGG16         rf  0.916844  0.012749  0.913858  0.013267  0.916847
# 14     Xception        svm  0.916493  0.010163  0.912831  0.010573  0.914920
# 5   InceptionV3        svm  0.908615  0.009643  0.904401  0.009215  0.906487
#
#                 Recall           Specificity             ROC AUC            \
#          std      mean       std        mean       std      mean       std
# 0   0.010752  0.916345  0.009144    0.973476  0.003092  0.989855  0.001672
# 2   0.011610  0.918123  0.010391    0.974049  0.003915  0.989629  0.002092
# 9   0.013545  0.913626  0.011950    0.972461  0.004008  0.988320  0.001904
# ...

# %%
top_acc = summary.sort_values(by=("Accuracy", "mean"), ascending=False).head(5)
print(top_acc)
# Out:
#    Architecture Classifier  Accuracy            F1 Score           Precision  \
#                                 mean       std      mean       std      mean
# 2   DenseNet121        svm  0.921570  0.011944  0.918660  0.011307  0.921714
# 0   DenseNet121         rf  0.919819  0.009786  0.916517  0.010328  0.918884
# 9         VGG16         rf  0.916844  0.012749  0.913858  0.013267  0.916847
# 14     Xception        svm  0.916493  0.010163  0.912831  0.010573  0.914920
# 5   InceptionV3        svm  0.908615  0.009643  0.904401  0.009215  0.906487
#
#                 Recall           Specificity             ROC AUC            \
#          std      mean       std        mean       std      mean       std
# 2   0.011610  0.918123  0.010391    0.974049  0.003915  0.989629  0.002092
# 0   0.010752  0.916345  0.009144    0.973476  0.003092  0.989855  0.001672
# 9   0.013545  0.913626  0.011950    0.972461  0.004008  0.988320  0.001904
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=all_results,
    x="Architecture",
    y="training_time",
    hue="Classifier"
)
plt.title("Training Time by Architecture and Classifier (10 folds)")
plt.ylabel("Time (seconds)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
